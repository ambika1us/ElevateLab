# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Superstore-Sales.csv',encoding="ISO-8859-1")

# %%
df.head(10)
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3  10/13/2010            Low               6    261.5400
# 1      49       293   10/1/2012           High              49  10123.0200
# 2      50       293   10/1/2012           High              27    244.5700
# 3      80       483   7/10/2011           High              30   4965.7595
# 4      85       515   8/28/2010  Not Specified              19    394.2700
# 5      86       515   8/28/2010  Not Specified              21    146.6900
# 6      97       613   6/17/2011           High              12     93.5400
# 7      98       613   6/17/2011           High              22    905.0800
# 8     103       643   3/24/2011           High              21   2781.8200
# 9     107       678   2/26/2010            Low              44    228.4100
#
#    Discount       Ship Mode   Profit  Unit Price  ...       Customer Name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   object
#  3   Order Priority        8399 non-null   object
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   object
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   object
#  12  Province              8399 non-null   object
#  13  Region                8399 non-null   object
#  14  Customer Segment      8399 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
new_df = df[["Order Date", "Region", "Product Category", "Sales", "Profit"]].copy()
new_df["Order Date"] = pd.to_datetime(new_df["Order Date"])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Date        8399 non-null   datetime64[ns]
#  1   Region            8399 non-null   object
#  2   Product Category  8399 non-null   object
#  3   Sales             8399 non-null   float64
#  4   Profit            8399 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 328.2+ KB

# %%
new_df.columns
# Out:
# Index(['Order Date', 'Region', 'Product Category', 'Sales', 'Profit', 'Month',
#        'Year'],
#       dtype='object')

# %%
#new_df["Month Name"] = new_df["Order Date"].dt.strftime("%B")  # Full month name
new_df["Month"] = new_df["Order Date"].dt.strftime("%b")  # Abbreviated (e.g., "Apr")
new_df["Year"] = new_df["Order Date"].dt.year

# %%
new_df['Month']
# Out:
# 0       Oct
# 1       Oct
# 2       Oct
# 3       Jul
# 4       Aug
#        ...
# 8394    Aug
# 8395    Aug
# 8396    Apr
# 8397    Apr
# 8398    Feb
# Name: Month, Length: 8399, dtype: object

# %%
new_df.to_csv("data.csv", index=False)
